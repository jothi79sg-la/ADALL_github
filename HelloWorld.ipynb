# %% [markdown]
# <a href="https://colab.research.google.com/github/jothi79sg-la/ADALL_github/blob/main/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print ("Hello World")
#print ("Hello World again")
import pandas as pd
# Example: Replace this with the raw URL of your GitHub file
github_raw_url = 'https://raw.githubusercontent.com/jothi79sg-la/ADALL_github/refs/heads/main/laptop_prices_2024_sgd_TL.csv'
try:
    df = pd.read_csv(github_raw_url)
    print("Successfully loaded data from GitHub!")
    display(df.head())
except Exception as e:
    print(f"Error loading data: {e}")
    print("Please ensure the URL is correct and the file format is compatible with `pd.read_csv`.")
# Out:
# Successfully loaded data from GitHub!
#   Brand                Model                        CPU              GPU  \
# 0  Acer             Aspire 5           Intel i9-14900HK  NVIDIA RTX 4070
# 1  Acer              Nitro 5         AMD Ryzen 9 8900HX  AMD Radeon 780M
# 2  Acer              Nitro 5          AMD Ryzen 5 8600H  NVIDIA RTX 4050
# 3  Acer        TravelMate P6  Intel Core Ultra 7 15500H  NVIDIA RTX 4060
# 4  Acer  Predator Helios 300            Intel i7-14800H  NVIDIA RTX 4070
#
#    RAM_GB Storage_Type  Storage_GB  Touchscreen  Weight_kg  Screen_Size_inch  \
# 0      64          SSD         256        False       1.56              16.0
# 1      32          SSD        1024         True       1.45              14.0
# 2      32          SSD        2048        False       1.34              14.0
# 3      16          SSD        4096         True       1.18              13.3
# 4       8          SSD        1024         True       1.31              14.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Identify numerical columns
numerical_cols = df.select_dtypes(include=['number']).columns

print(f"Generating histograms for {len(numerical_cols)} numerical columns:")

# Determine the number of rows and columns for the subplots
num_cols_per_row = 3
num_rows = math.ceil(len(numerical_cols) / num_cols_per_row)

fig, axes = plt.subplots(num_rows, num_cols_per_row, figsize=(num_cols_per_row * 6, num_rows * 5))
axes = axes.flatten() # Flatten the 2D array of axes for easy iteration

# Generate a histogram for each numerical column
for i, col in enumerate(numerical_cols):
    sns.histplot(df[col], kde=True, ax=axes[i])
    axes[i].set_title(f'Histogram of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')
    axes[i].grid(True, linestyle='--', alpha=0.7)

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout() # Adjust layout to prevent overlapping titles/labels
plt.show()
# Out:
# Generating histograms for 8 numerical columns:
